# %% [raw]
# ---
# title: "PA 7.1"
# author: "Mehrpad Moattari"
# date: "Nov 11, 2023"
# font-family: "serif"
# fontcolor: "steelblue"
# backgroundcolor: "whitesmoke"
# self-contained: true
# format:
#   html:
#     theme: "simplex"
# ---

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder, PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_scorehh

# %%
ames = pd.read_csv("C:/Users/mehrp/OneDrive/Documents/GitHub/PAs_7.1-7.2/AmesHousing.csv")

# %%
ames.head()
# Out:
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      1  526301100           20        RL         141.0     31770   Pave
# 1      2  526350040           20        RH          80.0     11622   Pave
# 2      3  526351010           20        RL          81.0     14267   Pave
# 3      4  526353030           20        RL          93.0     11160   Pave
# 4      5  527105010           60        RL          74.0     13830   Pave
#
#   Alley Lot Shape Land Contour  ... Pool Area Pool QC  Fence Misc Feature  \
# 0   NaN       IR1          Lvl  ...         0     NaN    NaN          NaN
# 1   NaN       Reg          Lvl  ...         0     NaN  MnPrv          NaN
# 2   NaN       IR1          Lvl  ...         0     NaN    NaN         Gar2
# 3   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 4   NaN       IR1          Lvl  ...         0     NaN  MnPrv          NaN
#
#   Misc Val Mo Sold Yr Sold Sale Type  Sale Condition  SalePrice
# 0        0       5    2010       WD           Normal     215000
# 1        0       6    2010       WD           Normal     105000
# 2    12500       6    2010       WD           Normal     172000
# 3        0       4    2010       WD           Normal     244000
# 4        0       3    2010       WD           Normal     189900
#
# [5 rows x 82 columns]

# %%
lr = LinearRegression()

X = ames[["Gr Liv Area", "TotRms AbvGrd", "Bldg Type", "Lot Area"]]
y = ames["SalePrice"]

#Split into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

#categorical and numerical columns
categorical_cols = [cname for cname in X_train.columns if X_train[cname].dtype == "object"]
numerical_cols = [cname for cname in X_train.columns if X_train[cname].dtype in ['int64', 'float64']]

#column transformer
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numerical_cols),
        ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_cols)
    ]
)


model = Pipeline(steps=[('preprocessor', preprocessor),
                        ('regressor', LinearRegression())])


model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['Gr Liv Area',
#                                                    'TotRms AbvGrd',
#                                                    'Lot Area']),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['Bldg Type'])])),
#                 ('regressor', LinearRegression())])

# %%
#using size and number of rooms
pipeline1 = Pipeline([
    ('scaling', StandardScaler()),
    ('regression', LinearRegression())
]).set_output(transform="pandas")

# Fit the pipeline
pipeline1.fit(X_train[['Gr Liv Area', 'TotRms AbvGrd']], y_train)


prediction1 = pipeline1.predict(X_test[['Gr Liv Area', 'TotRms AbvGrd']])
mean_prediction1 = np.mean(prediction1)
mean_prediction1
# Out:
# 184472.33179113804

# %%
rmse1 = mean_squared_error(y_test, prediction1, squared=False)
rmse1
# Out:
# 55372.45300785066

# %%
#using size, number of rooms, and building type
pipeline2 = Pipeline([
    ('preprocess', ColumnTransformer([
        ('num', StandardScaler(), ['Gr Liv Area', 'TotRms AbvGrd']),
        ("dummify", OneHotEncoder(sparse_output = False), ["Bldg Type"])
    ],
    remainder = "drop")),
    ('regression', LinearRegression())

])


pipeline2.fit(X_train[['Gr Liv Area', 'TotRms AbvGrd', 'Bldg Type']], y_train)


prediction2 = pipeline2.predict(X_test[['Gr Liv Area', 'TotRms AbvGrd', 'Bldg Type']])
mean_prediction1 = np.mean(prediction2)
mean_prediction1
# Out:
# 185603.771119978

# %%
rmse2 = mean_squared_error(y_test, prediction2, squared=False)
rmse2
# Out:
# 54083.12550273998

# %%
r_squared = pipeline2.score(X_test[['Gr Liv Area', 'TotRms AbvGrd', 'Bldg Type']], y_test)
r_squared
# Out:
# 0.5512204934420772

# %%
pipeline3 = Pipeline([
    ('preprocess', ColumnTransformer([
        ('num', PolynomialFeatures(degree=2, include_bias=False, interaction_only=True), ['Gr Liv Area']),
        ("dummify", OneHotEncoder(sparse_output = False), ["Bldg Type"])
    ])),
    ('regression', LinearRegression())
])


pipeline3.fit(X_train[['Gr Liv Area', 'Bldg Type']], y_train)


prediction3 = pipeline3.predict(X_test[['Gr Liv Area', 'Bldg Type']])
mean_prediction3 = np.mean(prediction2)
mean_prediction3
# Out:
# 185603.771119978

# %%
rmse3 = mean_squared_error(y_test, prediction3, squared=False)
rmse3
# Out:
# 54195.4480601071

# %%
pipeline4 = Pipeline([
    ('preprocess', ColumnTransformer([
        ('size_poly', PolynomialFeatures(degree=5), ['Gr Liv Area']),
        ('rooms_poly', PolynomialFeatures(degree=5), ['TotRms AbvGrd']),
        ("dummify", OneHotEncoder(sparse_output = False), ["Bldg Type"])
    ])),
    ('regression', LinearRegression())
])


pipeline4.fit(X_train[['Gr Liv Area', 'TotRms AbvGrd', 'Bldg Type']], y_train)


prediction4 = pipeline4.predict(X_test[['Gr Liv Area', 'TotRms AbvGrd', 'Bldg Type']])
mean_prediction4 = np.mean(prediction2)
mean_prediction4
# Out:
# 185603.771119978

# %%
rmse4 = mean_squared_error(y_test, prediction4, squared=False)
rmse4
# Out:
# 53218.39380275462

# %% [markdown]
# Best model based on RMSE is the model using size, number of rooms, and building type because its RMSE is the lowest.

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import make_scorer, mean_squared_error

rmse_scorer = make_scorer(mean_squared_error, squared=False)

scores = cross_val_score(pipeline1, X, y, cv=5, scoring=rmse_scorer)
print(scores)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Untitled-1.ipynb Cell 15 line 6
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X20sdW50aXRsZWQ%3D?line=1'>2</a> from sklearn.metrics import make_scorer, mean_squared_error
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X20sdW50aXRsZWQ%3D?line=3'>4</a> rmse_scorer = make_scorer(mean_squared_error, squared=False)
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X20sdW50aXRsZWQ%3D?line=5'>6</a> scores = cross_val_score(pipeline1, X, y, cv=5, scoring=rmse_scorer)
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X20sdW50aXRsZWQ%3D?line=6'>7</a> print(scores)
#
# File c:\Users\mehrp\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:562, in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     559 # To ensure multimetric format is not supported
#     560 scorer = check_scoring(estimator, scoring=scoring)
# --> 562 cv_results = cross_validate(
#     563     estimator=estimator,
#     564     X=X,
#     565     y=y,
#     566     groups=groups,
#     567     scoring={"score": scorer},
#     568     cv=cv,
#     569     n_jobs=n_jobs,
#     570     verbose=verbose,
#     571     fit_params=fit_params,
#     572     pre_dispatch=pre_dispatch,
#     573     error_score=error_score,
#     574 )
#     575 return cv_results["test_score"]
#
# File c:\Users\mehrp\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:211, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     205 try:
#     206     with config_context(
#     207         skip_parameter_validation=(
#     208             prefer_skip_nested_validation or global_skip_validation
#     209         )
#     210     ):
# --> 211         return func(*args, **kwargs)
#     212 except InvalidParameterError as e:
#     213     # When the function is just a wrapper around an estimator, we allow
#     214     # the function to delegate validation to the estimator, but we replace
#     215     # the name of the estimator by the name of the function in the error
#     216     # message to avoid confusion.
#     217     msg = re.sub(
#     218         r"parameter of \w+ must be",
#     219         f"parameter of {func.__qualname__} must be",
#     220         str(e),
#     221     )
#
# File c:\Users\mehrp\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:328, in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, return_indices, error_score)
#     308 parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
#     309 results = parallel(
#     310     delayed(_fit_and_score)(
#     311         clone(estimator),
#    (...)
#     325     for train, test in indices
#     326 )
# --> 328 _warn_or_raise_about_fit_failures(results, error_score)
#     330 # For callable scoring, the return type is only know after calling. If the
#     331 # return type is a dictionary, the error scores can now be inserted with
#     332 # the correct key.
#     333 if callable(scoring):
#
# File c:\Users\mehrp\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:414, in _warn_or_raise_about_fit_failures(results, error_score)
#     407 if num_failed_fits == num_fits:
#     408     all_fits_failed_message = (
#     409         f"\nAll the {num_fits} fits failed.\n"
#     410         "It is very likely that your model is misconfigured.\n"
#     411         "You can try to debug the error by setting error_score='raise'.\n\n"
#     412         f"Below are more details about the failures:\n{fit_errors_summary}"
#     413     )
# --> 414     raise ValueError(all_fits_failed_message)
#     416 else:
#     417     some_fits_failed_message = (
#     418         f"\n{num_failed_fits} fits failed out of a total of {num_fits}.\n"
#     419         "The score on these train-test partitions for these parameters"
#    (...)
#     423         f"Below are more details about the failures:\n{fit_errors_summary}"
#     424     )
#
# ValueError:
# All the 5 fits failed.
# It is very likely that your model is misconfigured.
# You can try to debug the error by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\mehrp\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\mehrp\anaconda3\Lib\site-packages\sklearn\base.py", line 1151, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\mehrp\anaconda3\Lib\site-packages\sklearn\pipeline.py", line 416, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\mehrp\anaconda3\Lib\site-packages\sklearn\pipeline.py", line 370, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\mehrp\anaconda3\Lib\site-packages\joblib\memory.py", line 349, in __call__
#     return self.func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\mehrp\anaconda3\Lib\site-packages\sklearn\pipeline.py", line 950, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\mehrp\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py", line 140, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\mehrp\anaconda3\Lib\site-packages\sklearn\base.py", line 918, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\mehrp\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py", line 837, in fit
#     return self.partial_fit(X, y, sample_weight)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\mehrp\anaconda3\Lib\site-packages\sklearn\base.py", line 1151, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\mehrp\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py", line 873, in partial_fit
#     X = self._validate_data(
#         ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\mehrp\anaconda3\Lib\site-packages\sklearn\base.py", line 604, in _validate_data
#     out = check_array(X, input_name="X", **check_params)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\mehrp\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 917, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\mehrp\anaconda3\Lib\site-packages\sklearn\utils\_array_api.py", line 380, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\mehrp\anaconda3\Lib\site-packages\pandas\core\generic.py", line 1998, in __array__
#     arr = np.asarray(values, dtype=dtype)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ValueError: could not convert string to float: '1Fam'

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import make_scorer, mean_squared_error

rmse_scorer = make_scorer(mean_squared_error, squared=False)

scores = cross_val_score(pipeline2, X, y, cv=5, scoring=rmse_scorer)
print(scores)
# Out:
# [59447.5945622  51677.04316677 57660.55257913 54423.45405505
#  47631.76278281]

# %%
scores.mean()
# Out:
# 54168.08142919383

# %%
rmse_scorer = make_scorer(mean_squared_error, squared=False)

scores = cross_val_score(pipeline3, X, y, cv=5, scoring=rmse_scorer)
print(scores)
# Out:
# [59148.73696256 52141.93955263 57470.44206793 54616.25407089
#  48345.40142339]

# %%
scores.mean()
# Out:
# 54344.55481548086

# %%
rmse_scorer = make_scorer(mean_squared_error, squared=False)

scores = cross_val_score(pipeline4, X, y, cv=5, scoring=rmse_scorer)
print(scores)
# Out:
# [61412.84577833 53487.89959464 62977.65732549 55348.05302977
#  48289.98763143]

# %% [markdown]
# My first model failed, but out of the ones that worked, model2 seemes to a the better performer becuause of the lower RMSE.

# %%
from sklearn.model_selection import GridSearchCV

pipeline = Pipeline([
    ('preprocessor', ColumnTransformer([
        ('size_poly', PolynomialFeatures(), ['Gr Liv Area']),
        ('rooms_poly', PolynomialFeatures(), ['TotRms AbvGrd']),
        ("dummify", OneHotEncoder(sparse_output = False), ["Bldg Type"])
    ])),
    ('regression', LinearRegression())
])


param_grid = {
    'preprocessor__size_poly__degree': range(1, 11),
    'preprocessor__rooms_poly__degree': range(1, 11),
}

# Set up the grid search
grid_search = GridSearchCV(pipeline, param_grid, cv=5, scoring='neg_mean_squared_error')

# Perform the grid search
gscv_fitted = grid_search.fit(X, y)
gscv_fitted.cv_results_
# Out:
# {'mean_fit_time': array([0.01165509, 0.01213984, 0.00987077, 0.01325197, 0.0163713 ,
#         0.02156954, 0.01510334, 0.03244987, 0.01397824, 0.02460175,
#         0.01450629, 0.0135118 , 0.02025023, 0.01348372, 0.01569519,
#         0.01870985, 0.01587505, 0.01686139, 0.01478243, 0.01403732,
#         0.01318612, 0.01286812, 0.01548176, 0.01712899, 0.01451483,
#         0.01384301, 0.01396079, 0.01471868, 0.01358695, 0.01399126,
, 2, 3, 4, 5, 6, 7, 8, 9, 10],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'preprocessor__rooms_poly__degree': 1,
#    'preprocessor__size_poly__degree': 1},
#   {'preprocessor__rooms_poly__degree': 1,
#    'preprocessor__size_poly__degree': 2},
#   {'preprocessor__rooms_poly__degree': 1,
#    'preprocessor__size_poly__degree': 3},
#   {'preprocessor__rooms_poly__degree': 1,
#    'preprocessor__size_poly__degree': 4},
#   {'preprocessor__rooms_poly__degree': 1,
#    'preprocessor__size_poly__degree': 5},
#   {'preprocessor__rooms_poly__degree': 1,
#    'preprocessor__size_poly__degree': 6},
#   {'preprocessor__rooms_poly__degree': 1,
#    'preprocessor__size_poly__degree': 7},
#   {'preprocessor__rooms_poly__degree': 1,
#    'preprocessor__size_poly__degree': 8},
#   {'preprocessor__rooms_poly__degree': 1,
#    'preprocessor__size_poly__degree': 9},
#   {'preprocessor__rooms_poly__degree': 1,
#    'preprocessor__size_poly__degree': 10},
#   {'preprocessor__rooms_poly__degree': 2,
#    'preprocessor__size_poly__degree': 1},
#   {'preprocessor__rooms_poly__degree': 2,
#    'preprocessor__size_poly__degree': 2},
#   {'preprocessor__rooms_poly__degree': 2,
#    'preprocessor__size_poly__degree': 3},
#   {'preprocessor__rooms_poly__degree': 2,
#    'preprocessor__size_poly__degree': 4},
#   {'preprocessor__rooms_poly__degree': 2,
#    'preprocessor__size_poly__degree': 5},
#   {'preprocessor__rooms_poly__degree': 2,
#    'preprocessor__size_poly__degree': 6},
#   {'preprocessor__rooms_poly__degree': 2,
#    'preprocessor__size_poly__degree': 7},
#   {'preprocessor__rooms_poly__degree': 2,
#    'preprocessor__size_poly__degree': 8},
#   {'preprocessor__rooms_poly__degree': 2,
#    'preprocessor__size_poly__degree': 9},
#   {'preprocessor__rooms_poly__degree': 2,
#    'preprocessor__size_poly__degree': 10},
#   {'preprocessor__rooms_poly__degree': 3,
#    'preprocessor__size_poly__degree': 1},
#   {'preprocessor__rooms_poly__degree': 3,
#    'preprocessor__size_poly__degree': 2},
#   {'preprocessor__rooms_poly__degree': 3,
#    'preprocessor__size_poly__degree': 3},
#   {'preprocessor__rooms_poly__degree': 3,
#    'preprocessor__size_poly__degree': 4},
#   {'preprocessor__rooms_poly__degree': 3,
#    'preprocessor__size_poly__degree': 5},
#   {'preprocessor__rooms_poly__degree': 3,
#    'preprocessor__size_poly__degree': 6},
#   {'preprocessor__rooms_poly__degree': 3,
#    'preprocessor__size_poly__degree': 7},
#   {'preprocessor__rooms_poly__degree': 3,
#    'preprocessor__size_poly__degree': 8},
#   {'preprocessor__rooms_poly__degree': 3,
#    'preprocessor__size_poly__degree': 9},
#   {'preprocessor__rooms_poly__degree': 3,
#    'preprocessor__size_poly__degree': 10},
#   {'preprocessor__rooms_poly__degree': 4,
#    'preprocessor__size_poly__degree': 1},
#   {'preprocessor__rooms_poly__degree': 4,
#    'preprocessor__size_poly__degree': 2},
#   {'preprocessor__rooms_poly__degree': 4,
#    'preprocessor__size_poly__degree': 3},
#   {'preprocessor__rooms_poly__degree': 4,
#    'preprocessor__size_poly__degree': 4},
#   {'preprocessor__rooms_poly__degree': 4,
#    'preprocessor__size_poly__degree': 5},
#   {'preprocessor__rooms_poly__degree': 4,
#    'preprocessor__size_poly__degree': 6},
#   {'preprocessor__rooms_poly__degree': 4,
#    'preprocessor__size_poly__degree': 7},
#   {'preprocessor__rooms_poly__degree': 4,
#    'preprocessor__size_poly__degree': 8},
#   {'preprocessor__rooms_poly__degree': 4,
#    'preprocessor__size_poly__degree': 9},
#   {'preprocessor__rooms_poly__degree': 4,
#    'preprocessor__size_poly__degree': 10},
#   {'preprocessor__rooms_poly__degree': 5,
#    'preprocessor__size_poly__degree': 1},
#   {'preprocessor__rooms_poly__degree': 5,
#    'preprocessor__size_poly__degree': 2},
#   {'preprocessor__rooms_poly__degree': 5,
#    'preprocessor__size_poly__degree': 3},
#   {'preprocessor__rooms_poly__degree': 5,
#    'preprocessor__size_poly__degree': 4},
#   {'preprocessor__rooms_poly__degree': 5,
#    'preprocessor__size_poly__degree': 5},
#   {'preprocessor__rooms_poly__degree': 5,
#    'preprocessor__size_poly__degree': 6},
#   {'preprocessor__rooms_poly__degree': 5,
#    'preprocessor__size_poly__degree': 7},
#   {'preprocessor__rooms_poly__degree': 5,
#    'preprocessor__size_poly__degree': 8},
#   {'preprocessor__rooms_poly__degree': 5,
#    'preprocessor__size_poly__degree': 9},
#   {'preprocessor__rooms_poly__degree': 5,
#    'preprocessor__size_poly__degree': 10},
#   {'preprocessor__rooms_poly__degree': 6,
#    'preprocessor__size_poly__degree': 1},
#   {'preprocessor__rooms_poly__degree': 6,
#    'preprocessor__size_poly__degree': 2},
#   {'preprocessor__rooms_poly__degree': 6,
#    'preprocessor__size_poly__degree': 3},
#   {'preprocessor__rooms_poly__degree': 6,
#    'preprocessor__size_poly__degree': 4},
#   {'preprocessor__rooms_poly__degree': 6,
#    'preprocessor__size_poly__degree': 5},
#   {'preprocessor__rooms_poly__degree': 6,
#    'preprocessor__size_poly__degree': 6},
#   {'preprocessor__rooms_poly__degree': 6,
#    'preprocessor__size_poly__degree': 7},
#   {'preprocessor__rooms_poly__degree': 6,
#    'preprocessor__size_poly__degree': 8},
#   {'preprocessor__rooms_poly__degree': 6,
#    'preprocessor__size_poly__degree': 9},
#   {'preprocessor__rooms_poly__degree': 6,
#    'preprocessor__size_poly__degree': 10},
#   {'preprocessor__rooms_poly__degree': 7,
#    'preprocessor__size_poly__degree': 1},
#   {'preprocessor__rooms_poly__degree': 7,
#    'preprocessor__size_poly__degree': 2},
#   {'preprocessor__rooms_poly__degree': 7,
#    'preprocessor__size_poly__degree': 3},
#   {'preprocessor__rooms_poly__degree': 7,
#    'preprocessor__size_poly__degree': 4},
#   {'preprocessor__rooms_poly__degree': 7,
#    'preprocessor__size_poly__degree': 5},
#   {'preprocessor__rooms_poly__degree': 7,
#    'preprocessor__size_poly__degree': 6},
#   {'preprocessor__rooms_poly__degree': 7,
#    'preprocessor__size_poly__degree': 7},
#   {'preprocessor__rooms_poly__degree': 7,
#    'preprocessor__size_poly__degree': 8},
#   {'preprocessor__rooms_poly__degree': 7,
#    'preprocessor__size_poly__degree': 9},
#   {'preprocessor__rooms_poly__degree': 7,
#    'preprocessor__size_poly__degree': 10},
#   {'preprocessor__rooms_poly__degree': 8,
#    'preprocessor__size_poly__degree': 1},
#   {'preprocessor__rooms_poly__degree': 8,
#    'preprocessor__size_poly__degree': 2},
#   {'preprocessor__rooms_poly__degree': 8,
#    'preprocessor__size_poly__degree': 3},
#   {'preprocessor__rooms_poly__degree': 8,
#    'preprocessor__size_poly__degree': 4},
#   {'preprocessor__rooms_poly__degree': 8,
#    'preprocessor__size_poly__degree': 5},
#   {'preprocessor__rooms_poly__degree': 8,
#    'preprocessor__size_poly__degree': 6},
#   {'preprocessor__rooms_poly__degree': 8,
#    'preprocessor__size_poly__degree': 7},
#   {'preprocessor__rooms_poly__degree': 8,
#    'preprocessor__size_poly__degree': 8},
#   {'preprocessor__rooms_poly__degree': 8,
#    'preprocessor__size_poly__degree': 9},
#   {'preprocessor__rooms_poly__degree': 8,
#    'preprocessor__size_poly__degree': 10},
#   {'preprocessor__rooms_poly__degree': 9,
#    'preprocessor__size_poly__degree': 1},
#   {'preprocessor__rooms_poly__degree': 9,
#    'preprocessor__size_poly__degree': 2},
#   {'preprocessor__rooms_poly__degree': 9,
#    'preprocessor__size_poly__degree': 3},
#   {'preprocessor__rooms_poly__degree': 9,
#    'preprocessor__size_poly__degree': 4},
#   {'preprocessor__rooms_poly__degree': 9,
#    'preprocessor__size_poly__degree': 5},
#   {'preprocessor__rooms_poly__degree': 9,
#    'preprocessor__size_poly__degree': 6},
#   {'preprocessor__rooms_poly__degree': 9,
#    'preprocessor__size_poly__degree': 7},
#   {'preprocessor__rooms_poly__degree': 9,
#    'preprocessor__size_poly__degree': 8},
#   {'preprocessor__rooms_poly__degree': 9,
#    'preprocessor__size_poly__degree': 9},
#   {'preprocessor__rooms_poly__degree': 9,
#    'preprocessor__size_poly__degree': 10},
#   {'preprocessor__rooms_poly__degree': 10,
#    'preprocessor__size_poly__degree': 1},
#   {'preprocessor__rooms_poly__degree': 10,
#    'preprocessor__size_poly__degree': 2},
#   {'preprocessor__rooms_poly__degree': 10,
#    'preprocessor__size_poly__degree': 3},
#   {'preprocessor__rooms_poly__degree': 10,
#    'preprocessor__size_poly__degree': 4},
#   {'preprocessor__rooms_poly__degree': 10,
#    'preprocessor__size_poly__degree': 5},
#   {'preprocessor__rooms_poly__degree': 10,
#    'preprocessor__size_poly__degree': 6},
#   {'preprocessor__rooms_poly__degree': 10,
#    'preprocessor__size_poly__degree': 7},
#   {'preprocessor__rooms_poly__degree': 10,
#    'preprocessor__size_poly__degree': 8},
#   {'preprocessor__rooms_poly__degree': 10,
#    'preprocessor__size_poly__degree': 9},
#   {'preprocessor__rooms_poly__degree': 10,
#    'preprocessor__size_poly__degree': 10}],
#  'split0_test_score': array([-3.53401650e+09, -3.53599539e+09, -3.43400019e+09, -3.44553359e+09,
#         -3.71145838e+09, -3.71481838e+09, -3.74491077e+09, -3.86422391e+09,
#         -4.12635102e+09, -4.51306472e+09, -3.62076477e+09, -3.55517923e+09,
#         -3.50613924e+09, -3.50610117e+09, -3.71145836e+09, -3.71481838e+09,
#         -3.74491077e+09, -3.86422391e+09, -4.12635102e+09, -4.51306472e+09,
#         -3.59258327e+09, -3.54277501e+09, -3.50433514e+09, -3.50279199e+09,
# %%
gscv_fitted.cv_results_['mean_test_score']
# Out:
# array([-2.95199396e+09, -2.92175413e+09, -2.79802096e+09, -2.84489892e+09,
#        -3.43303003e+09, -4.12239325e+09, -5.93838046e+09, -1.21074255e+10,
#        -3.49276540e+10, -1.10418635e+11, -2.95776263e+09, -2.94657669e+09,
#        -2.80530745e+09, -2.84386984e+09, -3.43303007e+09, -4.12239325e+09,
#        -5.93838046e+09, -1.21074255e+10, -3.49276540e+10, -1.10418635e+11,
#        -2.93244233e+09, -2.94118072e+09, -2.82269740e+09, -2.84314795e+09,
#        -3.12013546e+09, -4.12239325e+09, -5.93838046e+09, -1.21074255e+10,
#        -3.49276540e+10, -1.10418635e+11, -2.89181129e+09, -2.92746336e+09,
#        -2.84066759e+09, -2.80276247e+09, -3.17247052e+09, -4.12239325e+09,
#        -5.93838046e+09, -1.21074255e+10, -3.49276540e+10, -1.10418780e+11,
#        -2.89418084e+09, -2.96019306e+09, -2.86465615e+09, -2.80473018e+09,
#        -3.19880165e+09, -4.12239324e+09, -5.93838046e+09, -1.21074255e+10,
#        -3.49276395e+10, -1.10418780e+11, -2.93650960e+09, -2.93980364e+09,
#        -2.87504737e+09, -2.82750627e+09, -3.01900803e+09, -3.22823518e+09,
#        -5.93838046e+09, -1.21074250e+10, -3.49276395e+10, -1.10418780e+11,
#        -6.03813483e+09, -4.17270763e+09, -3.53581218e+09, -2.81903922e+09,
#        -3.05329983e+09, -3.19665521e+09, -5.93838045e+09, -1.21074250e+10,
#        -3.49276395e+10, -1.10418780e+11, -1.40210176e+10, -7.78449415e+09,
#        -3.66241549e+09, -4.69451005e+09, -3.55973767e+09, -4.28766114e+09,
#        -5.93838039e+09, -1.21074250e+10, -3.49276395e+10, -1.10418780e+11,
#        -4.74180276e+09, -3.22664379e+09, -1.37194481e+10, -6.32992933e+09,
#        -3.62232100e+09, -4.62274158e+09, -3.99831253e+09, -1.21074250e+10,
#        -3.49276395e+10, -1.10418560e+11, -1.26310941e+12, -1.29892196e+12,
#        -2.70716104e+12, -7.35137127e+09, -4.36820892e+09, -6.09026455e+09,
#        -3.74544187e+09, -1.21074250e+10, -3.49276645e+10, -1.10418560e+11])

# %%
df = pd.DataFrame(data = {
    "degrees": np.arange(1, 101),
    "scores": gscv_fitted.cv_results_['mean_test_score']
})

sorted_df = df.sort_values(by="scores", ascending=True)

sorted_df = sorted_df.reset_index(drop=True)

sorted_df
# Out:
#     degrees        scores
# 0        93 -2.707161e+12
# 1        92 -1.298922e+12
# 2        91 -1.263109e+12
# 3        60 -1.104188e+11
# 4        50 -1.104188e+11
# ..      ...           ...
# 95       64 -2.819039e+09
# 96       13 -2.805307e+09
# 97       44 -2.804730e+09
# 98       34 -2.802762e+09
# 99        3 -2.798021e+09
#
# [100 rows x 2 columns]

# %% [markdown]
# Question1:
#
# The 93rd model based on the cross-validation metrics.
#
# Question2:
#
# From my reserch, I would say that the time, high cost and the computing invovled are the downsides. Bayesian optimitziation and regulaziation are some methods to become more efficient when choosing smaller numbers.
